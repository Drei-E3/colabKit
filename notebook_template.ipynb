# %%
from google.colab import drive
import json

drive.mount('/content/drive')
config_path = '/content/drive/MyDrive/Colab Notebooks/.config/MyProject.conf'

with open(config_path, 'r') as f:
    config = json.load(f)
    # %cd {config['path']}
